# %% [markdown]
# # ELMO - TripleM

# %% [markdown]
# ## Install requirements

# %%
# !pip3 install allennlp
# !pip uninstall google-cloud
# !pip install --upgrade google-cloud-storage
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting allennlp
#   Downloading allennlp-2.9.3-py3-none-any.whl (719 kB)
#      |████████████████████████████████| 719 kB 5.2 MB/s
# Requirement already satisfied: torchvision<0.13.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.12.0+cu113)
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.9 MB/s
# Collecting typer>=0.4.1
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.21.6)
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.18.0.tar.gz (592 kB)
#      |████████████████████████████████| 592 kB 52.0 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.4.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.3.5.1)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.7/dist-packages (from allennlp) (4.64.0)
# Collecting cached-path<1.2.0,>=1.0.2
#   Downloading cached_path-1.1.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.1.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 42.6 MB/s
# Requirement already satisfied: spacy<3.3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (2.2.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.1.0)
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 48.2 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.2.5)
# Requirement already satisfied: torch<1.12.0,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from allennlp) (1.11.0+cu113)
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from allennlp) (8.13.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from allennlp) (3.6.4)
# Collecting filelock<3.7,>=3.3
#   Downloading filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Collecting fairscale==0.4.6
#   Downloading fairscale-0.4.6.tar.gz (248 kB)
#      |████████████████████████████████| 248 kB 60.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting wandb<0.13.0,>=0.10.0
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 43.2 MB/s
# Collecting transformers<4.19,>=4.1
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 48.3 MB/s
# Requirement already satisfied: lmdb in /usr/local/lib/python3.7/dist-packages (from allennlp) (0.99)
# Requirement already satisfied: requests>=2.18 in /usr/local/lib/python3.7/dist-packages (from allennlp) (2.23.0)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from cached-path<1.2.0,>=1.0.2->allennlp) (1.18.1)
# Collecting boto3<2.0,>=1.0
#   Downloading boto3-1.23.6-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 73.9 MB/s
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.7 MB/s
# Collecting botocore<1.27.0,>=1.26.6
#   Downloading botocore-1.26.6-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 44.7 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 4.4 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 70.6 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.27.0,>=1.26.6->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (2.8.2)
# Requirement already satisfied: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (0.4.1)
# Requirement already satisfied: google-auth>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (1.35.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (1.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (4.8)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (57.4.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (4.2.4)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (1.31.5)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (2022.1)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (3.17.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (1.56.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp) (3.13)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2.0->google-cloud-storage<3.0,>=1.0->cached-path<1.2.0,>=1.0.2->allennlp) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp) (2.10)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 51.0 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18->allennlp) (3.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (2.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (1.0.7)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (3.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3,>=2.1.0->allennlp) (0.9.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.0.16->allennlp) (3.8.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision<0.13.0,>=0.8.1->allennlp) (7.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<4.19,>=4.1->allennlp) (2019.12.20)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 48.3 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 47.1 MB/s
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 63.0 MB/s
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer>=0.4.1->allennlp) (7.1.2)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (2.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp) (5.4.8)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 69.1 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 69.5 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->allennlp) (1.5.2)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp) (1.11.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->allennlp) (21.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<4.19,>=4.1->allennlp) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->allennlp) (3.1.0)
# Building wheels for collected packages: fairscale, jsonnet, pathtools, sacremoses
#   Building wheel for fairscale (PEP 517) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.6-py3-none-any.whl size=307252 sha256=018d6bb455f67e9d8b388b1f3632c72b8609c91a373a7bf6f8686f363c7fd9d4
#   Stored in directory: /root/.cache/pip/wheels/4e/4f/0b/94c29ea06dfad93260cb0377855f87b7b863312317a7f69fe7
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.18.0-cp37-cp37m-linux_x86_64.whl size=3994519 sha256=556a0c14100a1c1a64bed7e9aab0b5a7b248f36589af761da02f3a1130aa3d60
#   Stored in directory: /root/.cache/pip/wheels/a9/63/f9/a653f9c21575e6ff271ee6a49939aa002005174cea6c35919d
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=c7eead8eccbece683b3d1e9d0a1af8465a541081fc99c613058913a26502a8db
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=da811ccd168b423712f94b9fc3dd32cbbe0fae9332192fe8e43f3b1f77796993
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built fairscale jsonnet pathtools sacremoses
# Installing collected packages: urllib3, jmespath, smmap, botocore, s3transfer, pyyaml, gitdb, filelock, tokenizers, shortuuid, setproctitle, sentry-sdk, sacremoses, pathtools, huggingface-hub, GitPython, docker-pycreds, boto3, wandb, typer, transformers, tensorboardX, sentencepiece, jsonnet, fairscale, cached-path, base58, allennlp
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.7.0
#     Uninstalling filelock-3.7.0:
#       Successfully uninstalled filelock-3.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed GitPython-3.1.27 allennlp-2.9.3 base58-2.1.1 boto3-1.23.6 botocore-1.26.6 cached-path-1.1.2 docker-pycreds-0.4.0 fairscale-0.4.6 filelock-3.6.0 gitdb-4.0.9 huggingface-hub-0.5.1 jmespath-1.0.0 jsonnet-0.18.0 pathtools-0.1.2 pyyaml-6.0 s3transfer-0.5.2 sacremoses-0.0.53 sentencepiece-0.1.96 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 tensorboardX-2.5 tokenizers-0.12.1 transformers-4.18.0 typer-0.4.1 urllib3-1.25.11 wandb-0.12.16
# WARNING: Skipping google-cloud as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (1.18.1)
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-2.3.0-py2.py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 5.4 MB/s
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage) (1.31.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage) (3.17.3)
# Collecting google-resumable-media>=2.3.2
#   Downloading google_resumable_media-2.3.3-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 5.6 MB/s
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage) (2.23.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage) (1.35.0)
# Collecting google-cloud-core<3.0dev,>=2.3.0
#   Downloading google_cloud_core-2.3.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (2022.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (57.4.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.56.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.2.8)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (1.25.11)
# Installing collected packages: google-crc32c, google-resumable-media, google-cloud-core, google-cloud-storage
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.18.1
#     Uninstalling google-cloud-storage-1.18.1:
#       Successfully uninstalled google-cloud-storage-1.18.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-translate 1.5.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.3.0 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-cloud-core<2.0dev,>=1.0.3, but you have google-cloud-core 2.3.0 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.3.0 which is incompatible.
# google-cloud-bigquery 1.21.0 requires google-cloud-core<2.0dev,>=1.0.3, but you have google-cloud-core 2.3.0 which is incompatible.
# google-cloud-bigquery 1.21.0 requires google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1, but you have google-resumable-media 2.3.3 which is incompatible.
# Successfully installed google-cloud-core-2.3.0 google-cloud-storage-2.3.0 google-crc32c-1.3.0 google-resumable-media-2.3.3

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from allennlp.data.token_indexers.elmo_indexer import ELMoCharacterMapper
from allennlp.modules.elmo import Elmo, batch_to_ids
from sklearn.model_selection import KFold

from allennlp.modules.token_embedders.elmo_token_embedder import ElmoTokenEmbedder

import warnings
from typing import Dict

import torch
from allennlp.data import Token, Vocabulary, TokenIndexer, Tokenizer
from allennlp.data.fields import ListField, TextField
from allennlp.data.token_indexers import (
    SingleIdTokenIndexer,
    TokenCharactersIndexer,
    ELMoTokenCharactersIndexer,
    PretrainedTransformerIndexer,
    PretrainedTransformerMismatchedIndexer,
)
from allennlp.data.tokenizers import (
    CharacterTokenizer,
    PretrainedTransformerTokenizer,
    SpacyTokenizer,
    WhitespaceTokenizer,
)
from allennlp.modules.seq2vec_encoders import CnnEncoder
from allennlp.modules.text_field_embedders import BasicTextFieldEmbedder
from allennlp.modules.token_embedders import (
    Embedding,
    TokenCharactersEncoder,
    ElmoTokenEmbedder,
    PretrainedTransformerEmbedder,
    PretrainedTransformerMismatchedEmbedder,
)
from allennlp.nn import util as nn_util

import zipfile
import numpy as np
import json
import random
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine
from sklearn.cluster import AgglomerativeClustering, SpectralClustering, DBSCAN
from collections import Counter
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
options_file_path="/content/gdrive/MyDrive/NLP_TripleM/slovenian-elmo/options.json"
weight_file_path="/content/gdrive/MyDrive/NLP_TripleM/slovenian-elmo/slovenian-elmo-weights.hdf5"

# %% [markdown]
# ## Utility functions

# %%
def cos_similarity(x, y):
    return np.dot(x, y) / (np.linalg.norm(x) * np.linalg.norm(y))

def remove_diplicate_sentences(a):
    b_set = set(map(tuple,a))  #need to convert the inner lists to tuples so they are hashable
    b = list(map(list,b_set)) #Now convert tuples back into lists (maybe unnecessary?)
    return b

def convert_to_lowercase(sentences):
    res=[]
    for i in sentences:
        res.append(list(map(str.lower,i)))
    return res

# %% [markdown]
# ## Load model

# %%
# Note the "1", since we want only 1 output representation for each token.
elmo = Elmo(options_file=options_file_path,
            weight_file=weight_file_path, num_output_representations=1, dropout=0)

# %% [markdown]
# ## Load data

# %%
with open('/content/gdrive/MyDrive/NLP_TripleM/ccGigaFida/results/data.json') as json_file:
    data = json.load(json_file)
with open('/content/gdrive/MyDrive/NLP_TripleM/ccGigaFida/results/data_lema.json') as json_file:
    data_lema = json.load(json_file)
with open('/content/gdrive/MyDrive/NLP_TripleM/ccGigaFida/results/data_pos.json') as json_file:
    data_len = json.load(json_file)

words = np.load("/content/gdrive/MyDrive/NLP_TripleM/ccGigaFida/words.npy")
words
# Out:
# array(['leto', 'dan', 'konec', 'svet', 'stran', 'mesto', 'šola', 'ura',
#        'beseda', 'pot', 'red', 'zakon', 'zadeva', 'srce', 'tema',
#        'resnica', 'moški', 'vloga', 'kraj', 'stanje', 'škoda', 'film',
#        'večer', 'vrh', 'jutro', 'kazen', 'oblast', 'račun', 'novica',
#        'milijon', 'par', 'krog', 'tip', 'punca', 'sila', 'vir', 'las',
#        'akcija', 'meter', 'prst', 'kri', 'stik', 'grad', 'znak', 'lik',
#        'direktor', 'vodja', 'raven', 'kolo', 'rob', 'gost', 'duh',
#        'praznik', 'vest', 'korist', 'vedenje', 'tek', 'kup', 'otok',
#        'razstava', 'bitje', 'motor', 'karta', 'nevarnost', 'hitrost',
#        'kos', 'zob', 'stroj', 'kamen', 'župan', 'šef', 'vrtec', 'kot',
#        'deček', 'avgust', 'tok', 'jezero', 'klop', 'čelo', 'hip', 'kupec',
#        'pojav', 'čaj', 'postava', 'dolg', 'standard', 'jesen', 'rak',
#        'grob', 'plus', 'les', 'vez', 'polica', 'minus', 'plan', 'posoda',
#        'restavracija', 'jok', 'krilo', 'sol', 'rod', 'stres', 'trditev',
#        'faks', 'sled', 'gol', 'župnik', 'servis', 'prid', 'ustava',
#        'mora', 'pop', 'lokal', 'prevod', 'bazen', 'veda', 'plaža',
#        'pesek', 'opravljanje', 'bolnica', 'hoja', 'raj', 'maček', 'baza',
#        'kocka', 'sejem', 'bar', 'hodnik', 'lisica', 'skala', 'lev', 'vek',
#        'talent', 'peč', 'termin', 'krivec', 'lega', 'tableta',
#        'pogajanje', 'obrat', 'kampanja', 'očka', 'med', 'stop', 'plast',
#        'golf', 'mina', 'kip', 'pod', 'para', 'prilika', 'slovo', 'piknik',
#        'boja', 'krajina', 'nona', 'odpuščanje', 'draga', 'faktor', 'bit',
#        'vodnik', 'razgled', 'popoldan', 'pol', 'obresti', 'paša', 'pust',
#        'teza', 'koda', 'predsodek', 'instrument', 'smuč', 'pečica',
#        'nestrpnost', 'lok', 'bob', 'obrt', 'kopanje', 'rez', 'pok',
#        'jarek', 'peščica', 'metal', 'palček', 'ruta', 'solo', 'hod'],
#       dtype='<U12')

# %%
min_number_of_words=8
for keyword in ['golf']:
    all_sentences2=data[keyword][:3000] 
    all_sentences_lema2=data_lema[keyword][:3000] 

    all_sentences = []
    all_sentences_lema = []
    for sentence, sentence_lema in zip(all_sentences2, all_sentences_lema2):
        if len(sentence) >= min_number_of_words and sentence_lema not in all_sentences_lema:
            all_sentences.append(sentence)
            all_sentences_lema.append(sentence_lema)
    
    #all_sentences = convert_to_lowercase(all_sentences)
    all_sentences = convert_to_lowercase(all_sentences)
    all_embeddings=np.zeros((len(all_sentences),1024))
    
    #character_ids = batch_to_ids(all_sentences)
    #embeddings = elmo(character_ids) #rip RAM
    
    for i in range(len(all_sentences)): #iterate through the sentences for the given keyword
        character_ids = batch_to_ids([all_sentences[i]])
        embeddings = elmo(character_ids)

        keyword_position = all_sentences_lema[i].index(keyword)
        
        all_embeddings[i,:]=embeddings['elmo_representations'][0].detach().numpy()[0][keyword_position]
        #IF YOU FEED ALL SENTENCE USE BELLOW
        #all_embeddings[i,:]=embeddings['elmo_representations'][0].detach().numpy()[i][keyword_position]
        
    
    break #this break means that we terminate on the first word
    
del embeddings

# %% [markdown]
# ## Calculate pairwise similarities

# %%
#The bigger it is the more similar the senctences 
similarities={}
for i in range(all_embeddings.shape[0]):
    for j in range(i+1,all_embeddings.shape[0],1):
        similarities[str(i)+'-'+str(j)] = cos_similarity(all_embeddings[i,:], all_embeddings[j,:])
        
similarities = dict(sorted(similarities.items(), key=lambda x:x[1]))

distance_matrix=(pairwise_distances(all_embeddings,metric="cosine"))
similarity_matrix=1-distance_matrix

# %% [markdown]
# ## Best in worst scores

# %%
similarities_keys = list(similarities.keys())
for key in similarities_keys[:10]:
    first_sentence_idx, second_sentence_idx = map(int, key.split('-'))
    first_sent, second_sent = ' '.join(all_sentences[first_sentence_idx]), ' '.join(all_sentences[second_sentence_idx])
    
    print(similarities[key])
    print("1)"+first_sent+'.\n2)'+second_sent+".")
    print('-----')
# Out:
# 0.1325801865482292
# 1)enega od golfov iz omejene serije teh ljudskih športnikov smo preizkusili tudi mi.
# 2)zaradi opisane ameriške logike je znanost prenehala biti posvečen azil elitni intelektualni golf klub in je postala enako negotova in kruta tekma kot ameriška hokejska liga znanstvenik se v svoji ligi obdrži le toliko časa dokler dosega kompetitivne rezultate.
# -----
# 0.14564062047174417
# 1)enega od golfov iz omejene serije teh ljudskih športnikov smo preizkusili tudi mi.
# 2)9.00 izven kontrole 9.30 ameriški gladiatorji 11.15 stoke 11.45 normal oddaja za invalidne osebe 12.15 nogomet 2. nemška zvezna liga 13.00 world soccer 13.30 šport moči 14.30 motobike 15.30 motorvision 16.30 warm up 18.00 namizni tenis 1. nemška zvezna liga 19.00 golf us masters 20.00 gillette world sport special 20.30 biljard 21.30 knockout magazin 22.15 wrestling spw 0.00 redki športi 0.30 redki športi 1.00 best direct.
# -----
# 0.14946752852991377
# 1)predsednik prvega celjskega golf kluba je borut sedovnik.
# 2)morda ste bili presenečeni da ste v prejšnji številki videli toliko golfov na kupu a dejstvo je da je golf med najbolj priljubljenimi znamkami avtomobilov pri nas.
# -----
# 0.15429781239782114
# 1)19.00 golf turnir v dubaju 3. dan. 20.00 šport po svetu.
# 2)enega od golfov iz omejene serije teh ljudskih športnikov smo preizkusili tudi mi.
# -----
# 0.15486251107225904
# 1)7.00 atletika svetovno prvenstvo atene grčija prenos 9.30 tenis atp turnir cincinnati zda 11.00 cart indycar lexington ohio zda 12.00 motociklizem euro open prenos 14.00 atletika svetovno prvenstvo atene grčija 15.00 golf prenos 16.30 atletika svetovno prvenstvo atene grčija prenos 20.00 touring car 20.30 cart indycar lexington ohio zda 21.00 cart indycar lexington ohio zda prenos dirke 23.00 atletika svetovno prvenstvo atene grčija 0.00 tenis atp turnir cincinnati zda 2.00 konec.
# 2)enega od golfov iz omejene serije teh ljudskih športnikov smo preizkusili tudi mi.
# -----
# 0.15964492090618787
# 1)enega od golfov iz omejene serije teh ljudskih športnikov smo preizkusili tudi mi.
# 2)kopitar prejšnji teden so kralji priredili dobrodelni golf turnir na katerem so zbrali sto tisoč dolarjev ki so jih spet namenili posebnemu programu otroške bolnišnice la kings bloodmobile.
# -----
# 0.1599518218653828
# 1)nekaj minut po trčenju je kljub hitri sinovi in zdravniški pomoči umrla njegova mama 74 letna magdalena z. po trku je passata v katerem sta bili še sopotnici ki sta bili hudo ranjeni odbilo s ceste še prej pa je trčil z alfo ki jo je za golfom peljala 20 letna tjaša p. iz kranjske gore.
# 2)8.00 transazija 9.00 floyd v ozu 9.30 okus po italiji 10.00 po vseh golf igriščih sveta 10.30 okus po franciji 11.00 na vrhu sveta 12.00 afriški šampanjski vlaki 13.00 capriceina potovanja 13.30 veliki pobeg 14.00 pot se nadaljuje 14.30 dubai 15.00 mississippi reka pesmi 16.00 transazija 17.00 turist 17.30 čez ekvator obe ameriki 18.00 sprehod po zemlji 18.30 avventura potovanja po italijanski kuhinji 19.00 pot se nadaljuje 19.30 dubai 20.00 največja potovanja na svetu 21.00 floyd v ozu 21.30 debeluh iz kenta 22.00 najdlje a najlepše 23.00 svoboden v divji afriki 23.30 na obzorju 0.00 dominikin planet 1.00 oceanija 1.30 veliki pobeg.
# -----
# 0.16093926891727758
# 1)nekaj minut po trčenju je kljub hitri sinovi in zdravniški pomoči umrla njegova mama 74 letna magdalena z. po trku je passata v katerem sta bili še sopotnici ki sta bili hudo ranjeni odbilo s ceste še prej pa je trčil z alfo ki jo je za golfom peljala 20 letna tjaša p. iz kranjske gore.
# 2)8.00 transazija 9.00 nad oblaki 9.30 okus po italiji 10.00 po vseh golf igriščih sveta 10.30 okus po franciji 11.00 na vrhu sveta 12.00 tropska potovanja 13.00 capriceina potovanja 13.30 veliki pobeg 14.00 okus po italiji 14.30 floyd v španiji 15.00 mississippi reka pesmi 16.00 transazija 17.00 turist 17.30 čez ekvator obe ameriki 18.00 sprehod po planetu zemlja 18.30 avventura potovanje po italijanski kuhinji 19.00 od pekinga do pariza 19.30 stopinje na planetu zemlja 20.00 največja potovanja na svetu 21.00 nad oblaki 21.30 debeluh iz kenta 22.00 najdlje a najlepše 23.00 zdravnikove stopinje 23.30 na obzorju 0.00 dominikin planet 1.00 oceanija 1.30 veliki pobeg.
# -----
# 0.16106332510119856
# 1)enega od golfov iz omejene serije teh ljudskih športnikov smo preizkusili tudi mi.
# 2)8.00 olympica zgodovina olimpijskih iger 8.30 dominion reklamna oddaja 9.00 action 10.00 superkros 11.00 oldtimer magazin 12.00 motocikli 13.00 zlata petdeseta formule 1 14.00 hitrostno drsanje 15.00 power time 16.00 ameriški gladiatorji 17.00 šport moči 18.00 oldtimer magazin 19.00 nba od znotraj 20.15 rokomet 1. nemška zvezna liga 22.15 športna poročila 22.30 sumo 23.30 golf evropska turneja 0.00 gillette world sport special 0.30 športna poročila 0.45 normal oddaja za invalidne osebe 1.15 best direct reklamna oddaja 1.45 akrobatski team.
# -----
# 0.16234466824618385
# 1)tako je očitno da večini še ni dostopen niti zahodni avtomobil nižjega ali srednjega cenovnega razreda malo je golfov ne prav veliko manjših renaultov nissanov toyot hyundaijev in podobnih vsakdanjih uporabnikov naših cest.
# 2)celoten izkupiček dražbe je skupaj s sredstvi zbranimi na golf turnirju z akcijo nearest to the pin znašal 2,5 milijona tolarjev.
# -----

# %% [markdown]
# ## Agglomerative clustering

# %%
# ‘complete’, ‘average’, ‘single’
clusters = AgglomerativeClustering(affinity='precomputed', linkage='single', n_clusters=2).fit(distance_matrix)
print(Counter(clusters.labels_))
# ‘complete’, ‘average’, ‘single’
clusters = AgglomerativeClustering(affinity='precomputed', linkage='average', n_clusters=2).fit(distance_matrix)
print(Counter(clusters.labels_))
# ‘complete’, ‘average’, ‘single’
clusters = AgglomerativeClustering(affinity='precomputed', linkage='complete', n_clusters=2).fit(distance_matrix)
print(Counter(clusters.labels_))
# Out:
# Counter({0: 2063, 1: 1})
# Counter({0: 2013, 1: 51})
# Counter({1: 1271, 0: 793})

# %%
import pandas as pd
our_word = "klop"
dataset = np.hstack((all_embeddings, np.transpose([clusters.labels_])))
columns = list(range(dataset.shape[1]))
columns[-1] = "y"
df = pd.DataFrame(dataset, columns = columns)
df.to_csv(f"/content/gdrive/MyDrive/NLP_TripleM/for_classification/{our_word}_hierarhical_ELMO.csv", index = False)

# %%
for i,label in enumerate(clusters.labels_):
    if label==0:
        print(i,':', ' '.join(all_sentences[i]))
# Out:
# 2 : na zatožni klopi se mora braniti zaradi spolne zlorabe mladoletnika
# 3 : po njegovem prepričanju želijo ustvariti nekakšno ravnovesje potem ko so na zatožno klop že spravili miloševića in milutinovića
# 4 : profesor sedi spredaj poleg voznika tovarišica inge se brezskrbno stiska z mundyjem na zadnji klopi
# 5 : vi pa mi že nehajte delati kurčevo senco reče in kljubovalno obsedi na klopi dokler ga profesor s saševo pomočjo ne dvigne na noge in odvede v avto
# 6 : kupi časopis sede na klop in opazuje svet ki hiti mimo prešine ga ali tudi svet opazuje njega
# 7 : zadnja klop pri audiju a3 seveda ni tako udobna in prostorna kot v osmici
# 8 : prtljažnik pa je za ta golfov razred pričakovano velik in meri 350 litrov pri podrti zadnji klopi pa dobite 1100 litrski prostor
# 9 : zadnje minute so minile v splošni norišnici na tribunah in na slovenski klopi v 13. medsebojni tekmi pa je slovenija sinoči dosegla četrto zmago
# 10 : in slabo uslugo bi si naredili če bi se začeli v vladnih klopeh ozirati po domačih izdajalcih ki so odtegnili svoj glas
# 11 : kljub temu pa sodišče njegovo dejanje gleda iz drugačne pravne perspektive in gilbert se kmalu znajde na zatožni klopi
# 13 : prtljažnik v osnovi meri 405 litrov ob povsem podrti klopi pa spodobnih 1410
# 14 : spomin mi ubeži v šolske klopi ko sem reševala matematične naloge in ko je ob meni stal profesor in spremljal moje računanje
# 15 : to bo spopad dveh odličnih obramb francozi pa imajo večje ustvarjalce v zvezni vrsti in širši izbor napadalcev na klopi
# 16 : ni jim bilo težko klečati ob klopi in moliti saj so vedeli da morajo boga pričakati z molitvijo
# 17 : njegov kolega na klopi zagrebčanov dražen anzulović je dodal zasluženo smo zmagali čeprav nismo prikazali najboljše igre
# 18 : trener spahija je roke igralcem in ostalim članom strokovnega štaba ki so sedeli na klopi stisnil že dobri dve minuti pred koncem tekme in s tem že takrat nakazal da je vsega konec
# 19 : slednji so še vedno na prostosti v srbiji jeremić pa se je znašel na zatožni klopi potem ko so ga lani na podlagi mednarodne tiralice v skopju aretirali makedonski policisti in ga izročili italijanskemu pravosodju
# 20 : bilo je 2:1 dina šeremeta tokrat ni bilo na gostujoči klopi za rezervne igralce
# 21 : denis žilavec ni sodeloval pri zmagi svoje ekipe sedel je na klopi za rezervne igralce
# 22 : bili smo brez šestih igralcev in na klopi brez pravih zamenjav za udarno enajsterico je priznal domači trener nikola ilievski
# 23 : na prednjih sedežih bosta dva odrasla sedela brez težav na zadnji klopi ki je za deset centimetrov višja kot prednja sedeža pa bodo uživali predvsem otroci
# 24 : v 3. nizu pa je meltal vodil kar s 24:8 in na vrsto je prišla tudi klop
# 25 : proti vsv ki igra najostreje od vseh klubov v mhl so ljubljančani na kazenski klopi presedeli kar 14 minut več od tekmecev
# 26 : z odsotnim pogledom je obtoženka zmedeno pogledovala po dvorani nakar je z utrujenimi drsečimi koraki stopila k zatožni klopi in s pomočjo paznic negotovo sedla
# 27 : številni majhni avti imajo namreč zadnjo klop deljivo zložljivo celo odstraniti se jo da in tako je mogoče prtljažnik na račun zmanjšanega potniškega prostora bistveno povečati
# 28 : žal se zgodba ne nadaljuje na zadnji klopi kjer je prostorska stiska precejšnja
# 29 : korejci bi zadrego zlahka rešili z vzdolžno pomično zadnjo klopjo podobno kot japonci pri toyoti yaris
# 30 : število otrok neitalijanskega porekla ki drgnejo italijanske šolske klopi je premosorazmerno z valovi priseljencev ki pljuskajo ob italijanske obale
# 31 : včeraj sta bila zaslišana še obtožena janja trček iz maribora in andrej magdič iz beltincev na zatožni klopi pa poleg lončariča sedijo še milenko lučič in njegova žena liljana ki je bila dolga leta zaposlena v administraciji na okrožnem državnem tožilstvu v ljubljani rajko turjačanin ernest verglest dominik ščavničar gregor janežič danijel lukač božidar mavrin simon kodelič matija bukovec in fatmir ahmetaj vsi pa so obtoženi kaznivega dejanja ilegalnega prehoda čez državno mejo
# 32 : prekaljena strateginja na klopi valencie cristina mayo je poskušala z vsem kar je imela na voljo
# 33 : pač ni premogla raznovrstnosti ki jo na svoji klopi ima tone tiselj in zanjo je bilo to žalostno slovo od najuspešnejšega rodu pri valencii ki je z morskovo na čelu naslov evropskih prvakinj osvojil leta 1997
# 34 : natakarji ki so po videzu sodeč še sami gulili šolske klopi so sto šestdeset na uro drveli po prostoru da jim je pot kapljal z obraza
# 35 : navdušen sem bil ko sem izvedel za pomično zadnjo klop s katero lahko skromni 40 cm globoki prtljažnik povečamo na 60 cm seveda ob žrtvovanju prostora za sopotnike
# 36 : v skrajnih primerih lahko v celoti podrete zadnjo klop kar pa ni bilo potrebno čeprav večkrat kaj tovorim in prevažam
# 37 : sedel sem na eno od klopi in se zagledal v nebo ki je vedno bolj rdelo
# 38 : najine sogovornike sedaj se jih je na klopi pred nama nabralo že kar nekaj pa je seveda zanimalo kaj počneva v kolumbiji
# 39 : tokrat proti ljudem ki so sedeli na klopi pred najbližjo hišo in naju napeto opazovali
# 40 : pred vrati v lopo je stala lesena klop
# 41 : in na to še pripomba iz svetniških klopi avšič ni bil kuhar ampak je posodo pomival
# 42 : model s petimi vrati dopušča tudi deljivo prevračanje zadnje klopi zato se z elantro lahko odpravite tudi po večjih nakupih
# 43 : ko je počival na klopi sredi gozda je k njemu pritekel trop otrok ter začudeno obstal pred možakom s sivo brado in lasmi
# 44 : priprave na turistično sezono klopi mize koši za odpadke itd. so že razporejeni po vsej občini te dni pa postavljajo še premične sanitarije ki bodo v grglju žlebeh na žagi v zavrtki in v fari na kamp zemljišču in še ob kolpi
# 45 : lymska ali lajmska borelioza je najpogostejša bolezen ki jo prenašajo klopi
# 47 : v imprezi boste lahko prepeljali tudi do pet oseb vseeno pa se morate zavedati da bo zadaj sedečim kolenskega prostora ob visokem vozniku in sovozniku zelo hitro zmanjkalo tako da je bolje da na zadnji klopi vozite otroke
# 48 : sponzorska pogodba za naslednjo sezono je sicer že sklenjena toda s funkcije predsednika je odstopil boris lebar od aktivnega igranja se je poslovila dolgoletna kapetanka saša vrbnjak bojana novaka pa ne bo več na ljutomerski trenerski klopi
# 49 : glin žagarstvo iz nazarij je predstavilo celoten proizvodni program ki zajema termoizolacijska okna in balkonska vrata fiksna in gibljiva polkna vrtne hišice in paviljone zložljive vrtne mize in klopi les za ostrešja masivne obloge žagan les in lepljene plošče
# 50 : ljubljana petindvajsetletni hajro beganović in prav toliko star arsim seferaj ki sta na zatožno klop sedla zaradi očitka da sta 29. marca v fužinskem a baru skušala umoriti faika nezovića bosta praznike preživela v priporu kjer bosta počakala tudi na nadaljevanje obravnave
# 51 : v tretjem so domače po nekaterih menjavah ko sta ostali na klopi pirherjeva in vrbnjakova le ujele pravi ritem
# 52 : stene pokritega stopnišča in čakalnice so popisane z grafiti vhodna vrata imajo razbito šipo klopi so v slabem stanju
# 53 : toda poslanec se je očitno odločil svoja v glavnem po slabem znamenita repliciranja iz poslanskih klopi razširiti na ves svet
# 54 : nekateri nosilci igre so zaradi evropske lige in potovanj že utrujeni zato je večjo minutažo dobila klop
# 55 : focus ima večji prtljažnik 385 litrov leon le 341 in več prostora na zadnji klopi
# 56 : na zatožni klopi so se poleg omenjenih treh našli tudi stanko senica iz senišč pri ormožu janez pool mlajši iz vadarcev in njegova izvenzakonska družica jožica merklin
# 57 : tujcev na trenerskih klopeh slovenskih prvoligašev je vse več neven spahija faruk kulenović dejan srzić mirsad alilović prav tako jih je nekaj celo v mladinskih kategorijah krka olimpija nova gorica in celo pionirskih mkk celje
# 58 : mi jih sprejmemo z odprtimi rokami domači pa sedijo na klopi in propadajo je za dnevnik pred kratkim povedal vodja slovenskih košarkarskih reprezentanc aleš pipan nekdanji trener krke
# 59 : sedi se visoko klop ponuja obilo prostora tako za noge kot glavo nekaj več litrov bi si želeli le v prtljažniku
# 60 : medtem pa so se mnogi šolarji prvič vzpenjali do šolskih klopi počitnice so se dokončno iztekle in začelo se je novo šolsko leto za 165.646 osnovnošolcev med njimi 18.384 prvošolcev
# 61 : na klopi v njem lahko delate poskoke ali pa se zabavate na otroškem igrišču kjer za dodatno kurjenje kalorij porivate otroka na gugalnici
# 62 : prehajamo k stališčem in sklepom ki ste jih prejeli tudi na klop to je pregled dodatnih stališč in sklepov
# 63 : krmar sedi na enojni klopi z dvižnim sedalnim delom ki zagotavlja udobno sedenje in stanje za volanskim obročem
# 64 : klopi in še dodatno krmarjeva klop na robu so odete v les kar daje mali francozinji še nekaj dodatnega čara
# 65 : odločitev kluba o višini zneska naj bi bila odvisna tudi od italijanske nogometne zveze ki se še ni odločila če bo cassano klop grel eno ali dve tekmi
# 66 : ta krma ploščad ima zelo prijetno lastnost da se v celoti potopi v vodo in je za kopalce pravzaprav klop pod vodo
# 67 : klop na krmni steni je dovolj velika za tri ljudi mizica pred njo pa za lačne goste
# 68 : že jutri bo v nikšiću sedel na zatožno klop univerzitetni profesor in predsednik opozicijske parlamentarne ljudske stranke dr. novak kilibarda
# 69 : imeli bodo tudi klopi in bodo zagotavlja izvajalec osvetljeni kjer bo to mogoče
# 70 : to da bodo prvi študenti medicine v mariborske šolske klopi sedli jeseni 2004 pa je po gabrovem mnenju optimistična napoved saj je treba postopke za vpis če bo seveda svet za visoko šolstvo dal zeleno luč kot je pojasnil vršilec dolžnosti rektorja univerze v mariboru dr. željko knez treba začeti že marca letos
# 71 : te zanima kako se šolskih klopi spominjajo slavni
# 72 : katarina čas voditeljica zmenkarij s kanala a je z malih ekranov izginila v študijske klopi in trenutno končuje zadnji letnik ekonomske fakultete v ljubljani
# 73 : 10 ograjeni vrt 14 družinski vrt 16 vrt za užitke 18 sadno zelenjavni vrt 20 vrt za ljubitelje 22 mehke in utrjene površine 24 utrjene površine tlakovani deli 26 zidovi ograje 28 žive meje oboki pergole obrobki 30 vodni deli vrta 32 vgrajene pritikline klopi razsvetljava 34 rastlinjaki kompostniki shrambe 36 rastline po namembnosti barva tekstura 38 kategorije rastlin 39 rastline za prijeten vonj središčne točke preprosto vzdrževanje prekrivanje mej in pregrad 40 načrtovanje zasaditve 40 cvetlične posode 42 urejanje zamisli 44 opomnik za načrtovanje 45 pregled obstoječega 46 načrtovanje sprememb 50 uresničitev načrta 52
# 74 : slabosti lepo oblikovane klopi iz kakovostnih gradiv so navadno zelo drage
# 75 : vonjave lepljiva evkrifija eucryphia glutinosa z dehtečimi belimi cvetovi posajena je lahko ob vrtni klopi
# 76 : slednji je tako odlično začel svojo trenersko kariero na klopi barce saj so bili njegovi nogometaši poleg milana pred dnevi po streljanju enajstmetrovk s 6:5 boljši tudi od juventusa
# 77 : na klopi je spet ostal gajser zaradi bojevite narave kot naročen za tekme s takimi tekmeci ki igrajo vseskozi na robu prekrška
# 78 : tako je zapenjanje lažje vstop do zadnje klopi pa še bolj olajšan
# 79 : enoprostorec bo imel vzdolžno pomično zadnjo klop in bo na trg prišel pomladi drugo leto
# 80 : torej če potniki niso pripeti z varnostnimi pasovi ker teh na zadnji klopi vozila ni naj sedijo na čimbolj varnih mestih
# 81 : predvsem je uporabna zadnja drsna klop ki lahko nudi prostor dvema potnikoma in s tem malce osvobodi prostor v prtljažniku ali pa se ustvari še peti sedež in s tem okrni prostor za kolena
# 82 : prtljažni prostor je seveda odvisno od pozicije klopi velik od 198 do 274 litrov
# 83 : drugo nekoliko redkejše obolenje ki ga prenašajo klopi je klopni meningoencefalitis
# 84 : vendar kmalu pričakujejo povečanje števila obolelih kajti klopi so najbolj dejavni od aprila do oktobra zato kar tri četrtine bolnikov odkrijejo od maja do septembra predvsem v poletnih mesecih
# 85 : če bi bilo posredovanje na kosovu kdaj predmet sojenja zaradi morebitnih zločinov bi bili v večini primerov na zatožni klopi američani
# 86 : lendava otroško igrišče v lendavskem mestnem parku si pravzaprav ne zasluži tega imena polomljene in zarjavele gugalnice tobogan in druga igrala uničene klopi med drobnim kamenjem pa plevel
# 87 : za njim je na zatožno klop sedel sreten petrovič ki tudi ni vedel za kaj gre
# 88 : sodelavci obešajo zastave praznijo smetnjake pripravljajo klopi in mize
# 89 : bosta morda zaradi čečenije na mednarodno zatožno klop sedla boris jelcin in vladimir putin
# 90 : njegov kolega na klopi bih fuad muzurović je tekmo ocenil takole poraz slovenije z grčijo z 0:3 nas ni zavedel
# 91 : pripomba iz klopi je bila da je šlo po ceni sodeč najbrž za mesojede trajnice
# 92 : začudil se je da klopi pod novomeško občino sedaj ni je pa mogoče da so vmes tudi nepridipravi saj se je že zgodilo da so jih ukradli
# 93 : ne glede na to je obljubil da bo klop v najkrajšem času na svojem mestu
# 94 : na zatožni klopi potrošnikov se je v zadnjem času pojavlja tudi avtohiša real
# 95 : nazadnje je iz klopi stopil tudi vaški veljak
# 96 : miza z dvema klopema je lahko uporabna jedilniška delovna ali igralna skupina sch 2 99 str. 25
# 97 : razočarani pa smo bili nad prostornostjo zadnje klopi ki glede na zunanje mere avta obljublja več
# 98 : koliko klopi za druženje in igralnih kotičkov je v naseljih
# 99 : spomnimo veselinovič je predsednik odbora za finance lds pisec strankinega volilnega programa po odhodu šefinje katarine kresal v vlado pa bi namesto nje moral sesti v poslanske klopi
# 100 : njegova nadgradnja v primerjavi s petvratnim meganom je privlačen zadek ki pospravi vsaj 524 litrov prtljage oziroma celo 1.600 ob podrti zadnji klopi
# 101 : nekaj časa ga je pazil celo 18 centimetrov manjši jure balažič ki pa si je hitro nabral štiri osebne napake tako da ga je skansi moral potegniti na klop kar se je izkazalo za enega od ključnih razlogov za padec krkine igre
# 102 : nyon disciplinska komisija evropske nogometne zveze uefa je portugalskega trenerja na klopi angleškega kluba chelsea joseja mourinha kaznovala z dvema tekmama prepovedi vodenja moštva v ligi prvakov
# 103 : stara lesena klop star kolonialni gugalnik hladilnik v katerem je bila le voda in najnujnejša zdravila obledela uokvirjena fotografija mame in očeta na steni pokvarjen televizor hreščeč radio na polici v kotu miza in to je bilo vse
# 104 : na zatožni klopi ljubljanskega sodišča se je včeraj že drugič v dveh dneh znašel nekdanji generalni direktor policije borut likar
# 105 : klopi so lahko prenašalci dveh nevarnih bolezni klopnega meningoencefalitisa in lymske borelioze
# 106 : po celotedenskem guljenju šolskih klopi si otroci zagotovo zaslužijo sprostitev
# 108 : ko me je sluza porinila v tablo si ji raje nesel posračkano torbo v klop je zatulil da se je premaknilo dvestokilsko mlinsko kolo
# 109 : medtem ko so na zatožno klop sedli 54 letni jožef kovač 50 letni zvonimir vojska 34 letni bojan makuc prav toliko star marko kos 27 letni bruno srebrnjak vsi so v priporu in 21 letna irena kos 57 letne veronike pirc tudi včeraj tako kot prejšnjič ni bilo v razpravno dvorano
# 110 : zdi pa se da bo hartmanov prostor na zatožni klopi ostal prazen saj niti mednarodne poizvedbe niti drugo policijsko delo za zdaj ni dalo sadov pri iskanju prvega človeka gorenjske heroinske naveze
# 111 : letos je črnogorski trener na klopi kraškega zidarja nizal uspehe vendar je konec leta zaradi denarno boljše ponudbe nepričakovano odšel k savinjskim hopsom ki so po slabem uvodu v sezono iskali uvrstitev med prvih šest
# 112 : za tistega ki raje sedi na soncu je pripravljena lesena klop
# 113 : v večfaznem sojenju sta se sedaj na zatožni klopi znašla mentor seferaj in peter založnik ki se sicer nahajata v priporu
# 114 : vidljivost nazaj tesna zadnja klop in dostop glasen motor zagonski ključ oddajnik včasih izgubi povezavo z avtomobilom ni merilnika temperature hladilne tekočine
# 115 : štirje bodo sedeli na nekoliko ozkih klopeh ob mizi ki se ji proti sredini lahkotno izvleče dodatni del da je več prostora zlasti za odlaganje
# 116 : sicer pa za ta oblikovno zanimiv fordov izdelek ki je na nek način pravzaprav najavil sedanji evropski preporod te znamke govori tudi prilagodljiva notranjost če si privoščimo dodaten strošek premično zadnjo klop ko lahko iz petsedežnika z manj prostora za noge torej za družinsko uporabo naredimo zelo udoben štirisedežnik kjer se tudi zadnja potnika počutita povsem neutesnjeno
# 117 : je pa tudi tretja možnost dobro znana in uporabljena ko sicer zadnjo klop nekoliko zapleteno lahko tudi preklopimo naprej in prostor povsem izrabimo za prtljago
# 118 : prisotnost priponk isofix na zadnjih klopi ni bila dovolj jasno označena
# 119 : 17.00 z občinskih klopi seja os cerklje 1. del pon.
# 120 : 17.00 z občinskih klopi seja os žirovnica 1. del pon.
# 121 : na zatožni klopi so sicer le štiri osebe medtem ko jih je 13 z bin ladnom na čelu še vedno na prostosti
# 122 : iz drave štrli lesena klop ki so jo razgrajači izpulili iz mesta pri vinoteki v vodnem stolpu in pognali v reko
# 123 : šolske klopi se mu ob vsem tem zdijo zelo zelo daleč a vendar je z njimi tesno povezan
# 124 : statut obtožencem zagotavlja pošteno in hitro sojenje to je pomembno ne le za obtožence ki so že sedli na zatožno klop temveč tudi za tiste ki še čakajo v priporu
# 125 : lepo izpeljan princip samonanašanja ki v praksi pomeni da bi režim lahko kritiziral samo tisti ki v njem ni sedel nikoli v šolsko klop obiskal zdravnika ali oddal pismo na pošti
# 126 : nekdanji nogometaš ki je največje uspehe v karieri dosegal v znanih tujih klubih je tudi ob trenerski klopi tako živahen kot je bil nekoč na igrišču
# 127 : v gozdovih sta najbolj nevarni klopni meningitis in lymska borelioza ki ju prenašajo okuženi klopi pogosto pa imajo ljudje v tem letnem času težave tudi s črevesnimi okužbami
# 128 : poleg zvonimirja vojske na zatožni klopi sedijo še domnevni vodja kriminalne združbe 54 letni jožef kovač 58 letna veronika pirc 34 letna bojan makuc in marko kos 27 letni bruno srebrnjak in 21 letna irena kos
# 129 : borut jarc je uspešno prestal ognjeni krst na klopi modro belih
# 130 : izvrsten je bil david sevčnikar medtem ko si domača ekipa s klopjo vred za pristop zasluži grajo
# 131 : klopi so zunanji zajedavci ki se hranijo z gostiteljevo krvjo praktično skozi celotno obdobje razvoja
# 132 : s prtljago torej v tem avtomobilu res ne sme biti zadreg saj že osnovnih 540 litrov presega povprečje tega velikostnega razreda z zlaganjem deljive zadnje klopi pa se poveča na celih 1700 litrov
# 133 : vseeno je bil v 32. minuti izid še 56:58 a je bil spet usoden vstop igralcev s klopi in že čez dve minuti so naši izgubljali z ogromnih 58:74
# 134 : ko zapušča osnovnošolske klopi nas je presenetil s svojimi odgovori
# 135 : očitno bo letos takšna usoda zorana lubeja slovenskega reprezentanta ki se je v minuli sezoni navajal na novo okolje in slog igranja letos pa se bo moral sprijazniti s statusom plačanega gledalca na klopi za rezervne igralce
# 136 : odigrali smo štiri prijateljske tekme in vse sem gledal s klopi
# 137 : občinstvo je že pošteno preklinjalo predvsem špansko sodnico cristino fernandez pineiro nad njenimi odločitvami pa niso ostali ravnodušni niti na slovenski klopi
# 138 : po nekaterih informacijah bo na poljskem vendarle ostal tudi andrej urlep ki naj bi na klopi anwila zamenjal hrvaškega strokovnjaka aleksandra petrovića
# 139 : velik je tudi 157 litrski prtljažnik ki ga z zlaganjem zadnje klopi povečaš do rekordnih 882 litrov
# 140 : v skupini bi jih bilo vsaj deset in vsak bi imel svoje mize klopi kurišče in smetnjak
# 141 : a lahko oče na vse to mirno gleda do klopi je precej daleč streha je visoko boki so široki tako caddyjev prtljažnik pogoltne za kar 1266 litrov prtljage
# 142 : stanley kumar je rekel stanley kumar dve klopi stran
# 143 : sylvester naveen je rekel sylvester naveen v sosednji klopi
# 144 : stene veže so bile bele in čiste miza in klopi pa iz temnega lesa
# 145 : nenadoma je preskočila zebro in se vzpela na krmo z zadnjimi tacami na trikotno klop kjer se stikata stranski klopi s prednjimi na robnico
# 146 : malce je oklevala nato pa se je znova vzpela na klop skočila čez zebro in izginila pod ponjavo
# 147 : hijena je izgubila ravnotežje in z glavo udarila ob klop na katero se je hotela povzpeti
# 148 : pri tem je tako rezko počilo da sem bil prepričan da sta se razleteli ali klop ali čeljust ali pa kar obe
# 149 : od kdovekod se je na stranski klopi vzel koščen rjavkast glodalec ves živčen in glasno cvileč
# 150 : vzpel se je s prednjimi šapami na klop in potisnil gobec v vedro
# 151 : za zdaj o njih še noče spregovoriti verjetno pa bo zgodbo povedal pred sodiščem če ga bodo v phnom penhu posadili na zatožno klop kot mu obljubljajo
# 152 : bojan prašnikar bo še pred zimo s klopi presedlal na selektorski stolček vendar naj bi v prihodnjih mesecih tudi v dvojni vlogi poskrbel za ustrezno zalogo točk in uvrstitev v 3. predkolo kvalifikacij za ligo prvakov
# 153 : glede na to da je bil včeraj v poslanskih klopeh skoraj ves cvet slovenske politike so pred dvorano zbrani novinarji tudi budno spremljali kdo bi se komu lahko nasmehnil saj bi to bila že osnova za nadaljnja razmišljanja o morebitnih koalicijskih povezavah ali celo o delitvi ministrskih mest
# 154 : pa se drug drugemu niso kaj pretirano nasmihali zato je še najbolj v oči padlo to da je tako v poslanski klopi kot na seji poslanske skupine lds poleg prvega moža lds in bodočega mandatarja sedel igor bavčar in ne tone rop
# 155 : na sodniški klopi miroslav garb poskus megafonskega atentata na predsednika države
# 156 : klop za izvajanje potiska s prsi in počepov
# 157 : to je klop ki ima tudi stojala za palico in jih lahko uporabite tudi pri počepih
# 158 : na tekmah na klopi ni videti živčen ne skače histerično ob igrišču kot počno nekateri trenerji
# 159 : čeprav je bil katanec na klopi eksplozivnejši brane ne more uiti primerjavam z njim
# 160 : v prtljažnik bo mogoče spraviti 452 litrov zadnja klop je deljiva v razmerju 70:30
# 161 : tudi če je kdo na klopi v parku zatopljen v list pred seboj bo včasih prav hvaležen za razvedrilo
# 162 : sodnik je ravnal modro in nikogar ni poslal na kazensko klop
# 163 : krško v ponedeljek je na zatožno klop okrožnega sodišča v krškem zopet sedla četverica mladeničev 31 letni albin božičnik iz brežic ki je še v priporu v novem mestu 27 letni mihael glogovšek iz artič in 28 letni robert bogovič iz arnovega sela ki so osumljeni da so se združili za neupravičeno prodajo mamil in 23 letni aleš frece iz brežic ki naj bi kot policist zlorabil osebne podatke pri preverjanju registrske tablice avtomobila s katerim se je vozil navidezni kupec tajni sodelavec policije kateremu je uspelo konec avgusta in v začetku septembra trikrat odkupiti po 50 gramov heroina
# 164 : keramične ploščice na fasadah na klopeh in vodnjakih v parkih na stenah v arkadnih hodnikih na oznakah za ulice na imenih hiš in restavracij kdo bi si mislil da so ploščice lahko tako uporabne
# 168 : v času ko so klopi najbolj aktivni se moramo gozda izogibati
# 170 : potrebno je še da se ob prihodu iz gozda ali narave natančno pregledamo se oprhamo in preiščemo tudi obleko saj se klop ne prime takoj
# 172 : prav zanimivo se je po skoraj štirih desetletjih ponovno usesti v prvošolsko klop
# 173 : a čeprav se je rahlo poškodovani boris gnjidić poškodba kolena še naprej le ogreval za krkino klopjo so njegovi soigralci po desetih zaporednih točkah clarencea gilberta dve trojki in ricka rickerta zabijanje in horak v 34. minuti prešli v vodstvo z 69:62
# 174 : na zatožno klop ga je namreč spravila njegova vrstnica in sicer zato ker jo je poljubil na ustnice brez njene privolitve
# 175 : wallander se je počasi zibal nazaj na gugalni klopi
# 176 : prvi koš iz igre je lahko dosegel šele v 16. minuti ko je janez krojač odšel na klop
# 177 : kapetan slovenije teoman alibegovič je bil prav tako zelo zadovoljen ko sva šla z gorencem v drugem polčasu na klop se nemci niso več znašli saj niso vedeli na koga naj usmerijo svojo obrambo
# 178 : po petardi je slekel dres in stekel proti klopi za rezervne igralce kjer je objel fizioterapevta bojana tajnška ter za svoje veselje dobil rumeni karton
# 179 : najprej je podrl garažna vrata nato pa trčil ob klop pred stanovanjsko hišo
# 180 : govorice o kanclerjevem skoku čez plot zaradi katerih se je britanski mail on sunday znašel celo na zatožni klopi je v nekem intervjuju sprožila bivša schroderjeva žena hiltrud hampel
# 181 : lukačeva je res odšla iz podjetja a se je nekdanja predsednica sindikata v leku iz poslanskih klopi vrnila kot delavska direktorica
# 182 : tam so igrišča klopi luči igrala peskovniki prostor za starejše
# 183 : slišim njegove korake ki se oddaljujejo potem zaslišim zvok s klopi pade lopar na tla
# 184 : čeprav je x3 manjši od x5 se zdi da je prostora v njegovi potniški kabini več prostorski izkoristek je v vseh pogledih soliden saj je sedenje spredaj in zadaj dovolj udobno poleg tega je za zadnjo klopjo še solidnih 480 litrov prtljažnika
# 185 : v neki livarni smo kupili noge za klop ki jo bomo postavili pred hišo
# 186 : zaslug za uspehe rudi nikoli ne pripisuje zgolj sebi ampak je ponosen na delavnost vseh članov od najmlajših ki niti še ne drgnejo šolskih klopi do veteranov z več kot osmimi križi na ramenih
# 187 : vseeno pa moramo omeniti še proces proti hudodelski združbi ki so jo beograjski mediji poimenovali firma pa se menda zdaj ne spominjajo več kdaj je 48 obtožencev za organizirano razpečevanje mamil pravzaprav prvič sedlo na zatožno klop posebnega sodišča
# 188 : na voljo so bila tudi stranišča in posebne marmorne klopi namenjene senatorjem in drugim častnim gostom
# 189 : beograd eden od voditeljev srbske demokratične opozicije zoran djindjić je v pogovoru za sobotno izdajo beograjskega dnevnika danas napovedal da bo moral nekdanji jugoslovanski predsednik slobodan milošević sesti na zatožno klop takoj ko bo srbija dobila ustrezno tožilstvo in sodstvo
# 190 : domača obramba se je potopila s peto osebno je moral na klop bukva kmalu za njim pa še leban
# 191 : london rocker peter buck eden izmed ustanoviteljev in sedanji kitarist skupine rem se je ta teden znašel na zatožni klopi na sodišču v londonu
# 192 : in bogov se kajpak ne poseda na zatožno klop njihovega dela se ne kritizira
# 193 : oltar in klopi so bile delo štefana šubica poslikali so jo leopold layer janez in jurij šubic
# 194 : pri vodstvu kluba so uresničili napovedi o prihodu tujca na trenersko klop čeprav je chris imes novi head coach ljubljanskim navijačem dobro znan
# 195 : usedla sem se na klop ko je mojo pozornost pritegnil starejši duhovnik impresivnega videza ki je hodil proti meni s šopkom belih in vijoličastih lilij v rokah
# 196 : slednji je tudi dokončno potrdil da bo moštvo v naslednji sezoni vodil fatih terim medtem ko se na klop juventusa vrača marcello lippi ki bo zamenjal carla ancelottija
# 197 : pri podiranju zadnje klopi nastane skoraj dva metra dolga ravna površina
# 198 : recimo leseno jelenovo glavo ali nad že omenjeno klopjo z razgledom na videz prave rogove ki rabijo za obešalnike
# 199 : poslancu ki je v klopeh lds nadomestil andreja gerenčerja ko je ta odšel v budimpešto za veleposlanika so žetalčani namenili devet desetin vseh svojih glasov in ga napravili za 90 odstotnega župana
# 200 : na zatožno klop je sedel v hamedanu kjer naj bi tudi užalil preroka mohameda
# 201 : v drugem polčasu je trener kamenica namesto jovičića in brumna v igro poslal kastelica in zrnića s klopi pa je potegnil še zadnja dva aduta za strele z zunanjih položajev vučičevića in simonovića
# 202 : morilsko orožje pištolo škorpijon z dušilcem zvoka naj bi mu za 220.000 tolarjev priskrbel igor miškovič ki bo zaradi pomoči pri kaznivem dejanju prav tako sedel na zatožno klop
# 203 : okoli gostilne bo na velikem vrtu še več klopi kjer bodo lahko postregli 300 obiskovalcem
# 204 : ko so spravili v zadrego sabonisa ki si je nabral pet osebnih napak v 16 minutah igre ter moral dokončno na klop v 31. minuti z mizernim izkupičkom 3 točk in 3 skokov so opravili polovico naloge delo pa je dokončal alberto herreros z izjemno strelsko predstavo
# 205 : čeprav se je rodil hrvaškim staršem in je ponosen da je slovenec se je odločil nadaljevati kariero na makedonski klopi
# 206 : poleg tega zelo malo naših nogometašev igra v evropskih ligah nekaj jih tam redno greje klop le malo pa jih je standardnih članov prve enajsterice
# 208 : ko se bo sojenje enkrat začelo se sirija lahko znajde na zatožni klopi
# 209 : veteran poslanskih klopi zadnji predsednik socialistične skupščine je bil izvoljen na listi sd kar je zahtevala nsi ki na prejšnjih volitvah podpredsednika iz opozicijskih vrst ni podprla nobene lastovke iz lds
# 210 : s slednjim ga povezujejo tretja pogrezljiva sedežna klop za dva otroka v prtljažniku prilagodljivo večanje in manjšanje števila sedežev ter kopica drobnih delov opreme v prid udobju ki predstavljajo outlander na način kakršnega pri drugih tovrstnih vozilih ne opazimo
# 211 : maribor na zatožno klop mariborskega okrožnega sodišča je včeraj sedel 31 letni kristijan kamenik slovenski javnosti znan z maratonskega in še trajajočega sodnega procesa za štirikratni umor v tekačevem
# 212 : gregorius se je v avli usedel na klop za vodstvo šole kjer je senhor cortês z okamnelim izrazom spremljal pradov govor
# 213 : slednji je namenjena vzdolžno drsna klop ki ta 3,75 metra dolg avto naredi mnogo večji
# 214 : klop z lahnim pritiskom na ročico porinemo naprej da je dovolj prostora za sedenje otrok s čimer prtljažnik povečamo na 330 litrov
# 215 : če sta v avtu samo dva se klop asimetrično zlaga do prtljažnih 910 litrov
# 216 : ko zadaj vozimo odrasla porinemo klop nazaj da dobita razkošen prostor za noge a v tem primeru ostane za prtljago samo 268 litrov
# 220 : klopi so najbolj agresivni zjutraj ko je v travi še rosa
# 222 : v prvem polčasu nisem stopil na igrišče vendar sem bil presrečen že zato da sem sedel na klopi
# 223 : poleg izkušenj na domačih terenih in v domačih študijskih klopeh sem si pridobil dragocene izkušnje tudi na drugih koncih sveta od zanzibarja in egipta do večletnega igranja v indonezijskih in turških zasedbah
# 224 : priljubljeno shajališče je pivnica macksa lbryggerija v klopu katere je seveda tudi najbolj severno ležeča pivovarna
# 225 : to je storil zato ker mariji kamenik zaradi mamil ne morejo soditi ločeno za kristijana kamenika ki je priprt v beogradu pa ne more nihče napovedati kdaj se bo vrnil v slovenijo in na celjskem okrožnem sodišču skupaj z materjo in še tremi obtoženci sedel na zatožno klop zaradi obtožbe da so leta 1999 trgovali z mamili
# 226 : težko je bilo znova sesti v šolske klopi a smo kljub temu tvegali
# 227 : če do jutri ne bo poravnal še večjega obroka bo moral na zatožno klop
# 228 : prvič so v gimnazijske šolske klopi sedli fantje leta 1905 s šolskim letom 1912 13 pa je gimnazija postala popolna z vsemi osmimi razredi
# 229 : ukrajinec na olimpijini klopi pavel čumakov je bil besen kot ris njegova ocena pa kratka glede na to da smo prejeli samo 20 zadetkov bi morali zmagati
# 230 : zapihal je nov veter z vrnitvijo prof. jankoviča na novomeško odbojkarsko trenersko klop je v ok pionir zapihal nov veter
# 231 : njegova glavna težava je prekratka klop in pomanjkanje stalnih težkih tekem pri čemer kandija tudi po nedeljski tekmi ni pozabil okrcati vodstva robita olimpije ki noče igrati medsebojnih tekem za trening s krimom
# 232 : naenkrat se vse glave v razredu sunkovito obrnejo za 180 stopinj in z začudenjem buljijo vame ki zaradi šoka ne sedim več na stolu v zadnji klopi ampak poskušam s tal čimbolj neopazno pobrati zadnjo plat
# 237 : ko sem prišel do cheja je sedel na klopi
# 238 : oče matjaž na reprezentančni trenerski klopi na kateri se je že prej imenitno uveljavljal s finskim strokovnjakom karijem savolainenom zdaj pa je tu glavni in odgovorni ted sator ki hoče slovenski hokejski voz potegniti prav v svojo severno ameriko kjer bo naslednje leto svetovno prvenstvo
# 239 : publikum korotan gospod trener malo sedite in si odpočijte je sredi prvega polčasa dolgočasne tekme sodnik milan mitrović ošvrknil obe klopi
# 240 : nezadovoljni navijači po seriji neuspehov že napovedujejo da bo prašnikarjeva jubilejna 25. tekma na slovenski klopi tudi zadnja
# 241 : jadrnico je polagalo da smo se opirali ob klopi
# 242 : tudi maja ima svojo najboljšo prijateljico martino s katero sta skupaj žulili klopi na ekonomski fakulteti
# 243 : sam sem na klopi zdržal do konca sezone ko pa so mi bili ob koncu še dolžni sem split zapustil tudi sam
# 245 : ljudem ki jih je pičil klop ki prenaša lymsko boreliozo so nekateri zdravniki že prej dajali antibiotike temu so nasprotovali številni strokovnjaki ker ni bilo pravih dokazov da takšno zdravljenje res preprečuje bolezen čeprav je res da antibiotiki boreliozo po izbruhu uspešno zdravijo
# 247 : tako ima objemke za pritrditev tovora oziroma velike mreže skorajda prek vse prtljažne površine ki jo je mogoče zatakniti tudi navpično na naslonjalo klopi
# 248 : toda čotar je že na klopi prul 67 pokazal da mu je korekten odnos najpomembnejši
# 249 : klop zaletel sadar a. muminovič e. muminovič pandža velič
# 250 : sesedel se je na klop v kotu jedilnice
# 251 : poleg kovačiča so na zatožno klop koprskega sodišča sedli še miran rep iz vojnika tina gnilšek iz ljubljane miro simeunovič iz ljubljane ter mirko maček in zvezdan peroša iz izole
# 252 : za poskušnjo sem sedla na hladno kamnito klop na enega od šest tisoč sedežev in si skušala priklicati pred oči čas izpred dveh tisočletij ko je bila ta izsušena dežela ena tistih desetih na svetu ki jim najbolj primanjkuje vode bolj zelena in precej rodovitnejša in se je amanu reklo filadelfija kar pomeni mesto bratovske ljubezni
# 253 : če se štirje zagovorniki stiskajo za eno mizo in zaradi skopo odmerjenega prostora ne morejo odpreti niti spisa pred sabo prepolne pa so tudi klopi za priče in javnost se obravnava le stežka odvija še posebej če teče beseda o domnevni vpletenosti v 2,2 milijarde vredno oškodovanje volksbank ljudske banke
# 254 : stojan auer bo na zatožno klop znova sedel danes
# 255 : v igri je zdržal pičlih 12 minut pred dokončnim odhodom na klop pa mu je uspelo le enkrat metati na koš brez uspeha
# 256 : le 12 sekund zatem ko se je na kazenski klopi mitji robarju pridružil damjan dervarič je prednost dveh igralcev na ledu izkoristil elick nato pa je peintner po sodnikovem metu preigral dva igralca in še drugič premagal jeseniškega vratarja gabra glaviča
# 257 : v zadnjem delu so v dresu piacenze na parket stopili tudi fantje s klopi kar so kanalci izkoristili in tekmecem niso dovolili da bi se odlepili
# 258 : ultras ki so ta trenutek na zatožni klopi imajo brezplačen vstop na štadione vozijo jih s seboj na gostovanja plačujejo jim posebne prevoze in hrano
# 259 : sežanci so se z agresivno igro v 25. minuti sicer približali na 43:49 za kaj več pa ob zelo kratki klopi niso imeli moči
# 260 : ko so gostitelji v 33. minuti vodili s 77:52 je rannikko ob splošnih ovacijah sedel na klop in prepustil krmilo abdulu millsu vendar se je štiri minute pred koncem moral vrniti na igrišče saj je zadar z nizom 17:2 za hip celo ogrozil zmago tivolske zasedbe
# 261 : osrednja ključavnica volan s servoojačevalnikom in nedeljiva tretja klop so del srednjega paketa opreme ambiance
# 262 : vrhunec ponudbe je laureate ki vključuje električni pomik stekel in vzvratnih ogledal potovalni računalnik deljivo zadnjo klop in podobno
# 263 : valencia je namreč v sinočnjem derbiju porazila barcelono sodnik je pokazal 8 rumenih in dva rdeča kartona katere trener frank rijkaard je vendarle potrdil da bo na vroči klopi ostal tudi po koncu sezone
# 264 : tako je na klopi tokrat sedel časarjev pomočnik niko bernard priložnost v udarni zasedbi pa sta dobili petra kobe in tanja dimič ter jo dobro izkoristili
# 265 : le zanašati se ne smemo da recimo partizan tokrat prihaja oslabljen vujošević bo verjetno celo sedel za klopjo in taktika se tako ne bo spremenila medtem ko je tripković res pomemben člen
# 266 : kratka klop ki naj bi jo vendarle podaljšali slovenski legionarji drago vuković gorenje denis špoljarić celje pl in denis buntić cimos bo bržkone še naprej šibka točka peklenskih ki bodo morali na poti do vrha odigrati 10 tekem
# 267 : to se sicer ne ujema s kuloarskimi govoricami po katerih bo kamenica na celjski klopi najdlje do konca sezone na vrhu seznama kandidatov za novega trenerja pa sta velimir kljaić in sead hasanefendić
# 268 : prvi je na zatožno klop sedel bivši delavski direktor vw peter hartz
# 269 : toda že prvi ki je sedel na zatožno klop maročan rabej osman sajed ahmed znan tudi kot egipčan mohamed je izjavil da se ne bo izrekel o krivdi in se bo zagovarjal z molkom govoril da ne bo niti s predstavniki obrambe
# 270 : v streljanju je bil ranjen 16 letnik ki so ga krogle zadele v trebuh in stegno včeraj pa sta na zatožno klop ljubljanskega okrožnega sodišča sedla strelca 32 letni ibro pljaskovič in 17 letni mladenič
# 271 : maribor televizijski zvezdnik stojan auer ki je zaslovel z oddajo poglej in zadeni je znova sedel na zatožno klop saj mu tožilstvo očita poskus storitve kaznivega dejanja davčne zatajitve
# 272 : tradicijo lepih vrtov zaznajo obiskovalci v kvadratu striženih lipovih dreves vodnjakih lepih klopeh in sedežih ter nasadu vrtnic
# 273 : opozicija pa se bo morala vrniti v parlamentarne klopi če bo hotela upravičiti glasove svojih volilcev in svoji državi želeti dobro
# 275 : prav ti ki sedaj pridno gulijo šolske klopi in študirajo ti ki jim je že tečno poslušati zdrahe okrog bele ali sive knjige in shodov prav ti bodo posledice predlaganih reform najbolj čutili
# 276 : kolega z grške klopi panajotis janakis pa se je na široko razgovoril že pogled na statistične podatke pove da smo imeli slab večer saj smo metali le 28 odstotno
# 277 : še več lukenj pa je bilo v napadu celo najboljši mož aleš pajovič bi moral da bi si odpočil občasno na klop
# 278 : njegov načrt je bil tokrat enak sledila pa je kontradikcija z aktiviranjem cele klopi v odločilnih 20 minutah tekme
# 279 : islandec na nemški klopi alfred gislason pa je žarel od sreče ponosen sem na svoje može fantastični so bili izločili so eno najboljših ekip na svetu
# 280 : v skupini b je lada napovedala da navkljub temu da na klopi ni več jevgenija trefilova in da jih je zapustilo precej igralk misli resno na roke pa jim je šel tudi poraz budućnosti na domačem igrišču
# 281 : gostujoča klop je dobesedno popadala na kolena domžalčani pa krenili v zadnji napad
# 282 : najtežje je gledati in spremljati tekme s klopi ali tribune
# 283 : marko kmetec je sedel na klopi za rezervne igralce
# 284 : juventus in barcelona se za menjavo po vsej verjetnosti prav tako ne bosta odločila milan pa bo v primeru slovesa carla ancelottija na klop vnovič posadil enega svojih nekdanjih nogometašev
# 285 : mourinho kaj lahko bi se zgodilo da bi najpozneje v prihodnji sezoni jose mourinho s klopi vodil nogometaše madridskega reala
# 286 : r. smitha 24 točk ki je v igro vstopil s klopi saj sta nadoknadila izostanek carmela anthonyja ki je bil pred suspenzom zaradi pretepa sredi decembra v new yorku prvi strelec lige ter tudi 13 točk zaostanka nuggetsov za raketami
# 287 : res je da so proti šentvidčankam nastopile oslabljene prav tako na klopi ni bilo jožeta časarja pač pa je ekipo vodil njegov pomočnik niko bernard vendar to uspeha domače ekipe prav nič ne zmanjšuje
# 288 : ni ne bolan ne poškodovan a ocenil sem da bi mu počitek prišel še kako prav je dejal bečirovič tekmec s koprske klopi mihajlo poček pa dodal ekipa heliosa je trenutno skupaj z unionom olimpijo najboljša v sloveniji
# 289 : v drugem delu sta trenerja ponudila priložnost igralcem s klopi
# 290 : zagorje namreč v dosedanjih treh tekmah ni bilo popolno tokrat pa ima kolega na nasprotni klopi popolno postavo
# 291 : poleg brečka preglja in stevanoviča selektor matjaž kek zaradi poškodbe za svojo prvo tekmo na klopi a reprezentance ne bo mogel računati tudi na cimerotiča
# 292 : istočasno bo tudi zanimivo videti sicer posredni dvoboj novakoviča na klopi in jurkoviča na parketu nekdanjih odličnih soigralcev v dresu mostarske lokomotive in rogaške
# 293 : okorn se je sicer zelo jezil na sodnike in dobil tudi tehnično napako drugo pa njegova klop vendar so delivci pravice sašo pukl matej boltauzer in roman kolar svoje delo opravili povsem zadovoljivo
# 294 : zavedamo se da bo zaradi kratke klopi to težko toda druge izbire nimamo je odločen trboveljski strateg ki resnici na ljubo kaj dosti izbire tudi nima
# 295 : na eni od tekem smo igralci na klopi pri prednosti 30 točk v igro poslali enega od soigralcev ki do takrat edini še ni igral čeprav mu trener tega ni naročil
# 296 : rekli smo mu da mu je in usedel se je na klop za zamenjavo
# 297 : italijanski trener claudio ranieri ki je v svoji karieri sedel na klopeh domačih cagliarija napolija in fiorentine ter španskih valencie in atletica od leta 2000 do 2004 pa je vodil tudi chelsea je včeraj postal trener parme ki je trenutno na predzadnjem mestu v serie a. šestinpetdesetletni strokovnjak je zamenjal stefana piolija ki ga je klubsko vodstvo odpustilo po novem prvenstvenem porazu v nedeljo proti romi
# 298 : pametna in disciplinirana igra predvsem pa učinkovitost z igralcem več so bili tokrat ključ do uspeha rdečih proti rumenim ki so kar polovico tekme presedeli na kazenski klopi kar je bil gotovo eden od glavnih razlogov za poraz čete matjaža mahkovca ni pa jim pomagala niti menjava v vratih ko je anžeta ulčarja po šestem prejetem zadetku zamenjal matej mišič
# 299 : kako komentirate izjavo da tudi beckham in ronaldo sedita na klopi
# 300 : fritza prvega nemškega vratarja serdarušić že nekaj časa hladi na klopi in tribuni nemški selektor heiner brand je stopil na vratarjevo stran del nemških medijev ravno tako
# 301 : veselje v dvorani in predvsem na slovenski klopi je bilo nepopisno
# 302 : slednjemu bo na klopi pomagal mladi nikola bistrovič
# 303 : ta klub je v soboto doma remiziral 1:1 z auxerrom na klopi katerega je sedel naš mladi vratar denis petrič
# 304 : slednji je moštvo cagliarija že vodil in sicer je bil na njegovi klopi prvih šestnajst krogov tekočega prvenstva
# 305 : torres je zablestel javnost je bila navdušena španski novinarski kolegi niso mogli verjeti svojim očem capello pa se je prvič odkar je drugič v svoji trenerski karieri sedel na klop reala lahko upravičeno potolkel po prsih
# 306 : na prvih štirih tekmah ki jih je stoudemire začel na klopi je bilo razmerje zmag in porazov phoenixa 1:3 odkar ga trener mike d'antoni uvršča v prvo peterko pa imajo sonca razmerje v zmagah 42:10
# 307 : ante šimundža se vrača v ljudski vrt toda na celjski klopi
# 308 : klop 22 sušnik 3 pranjič 11 urbanč 20 biščan 17 korun 13 bakarič
# 309 : klop 30 baloh 15 škerjanc 5 baša 26 vidic 24 kosmač 17 kreft 2 mehanovič
# 310 : prav tako se mi zdi da imajo jutrišnji domačini nekoliko boljšo ekipo od drave zanemariti ne gre niti dejstva da na klopi primorja sedi bojan prašnikar
# 311 : igrali smo boljše toda menim da fantom manjka še malo samozavesti je povedal glavni na klopi rumeno črnih matjaž mahkovec
# 312 : jasno nam je da bodo gostitelji po spremembi na klopi polni motivov toda igramo dobro imamo svoj sistem dali bomo vse od sebe in če bo to dovolj se lahko nadejamo tudi kakšnemu presenečenju
# 313 : klop 31 šeliga 3 pranjič 4 križnik 11 urbanč 17 korun 20 biščan
# 314 : priznamo pričakovali smo celo da italijanski strateg v primeru neuspeha na bavarskem el clasica sploh ne bo dočakal na klopi toda če nekoliko premislimo so pri realu vendarle ravnali prav ko so capellu dovolili moštvo voditi tudi nocoj
# 315 : v drugi četrtini so zaigrali nekoliko manj zavzeto trener okorn pa je ponudil priložnost tudi igralcem s klopi
# 316 : duisburg je namreč včeraj izgubil še drugo tekmo zapored brez kaznovanega klemna lavriča doma je položil orožje pred fürthom aleša kokota in dejana kelharja znova ni bilo niti na klopi za rezervne igralce bilo je 0:2 0:0 kar je bil sicer že tretji zaporedni poraz zeber
# 317 : kakovostna razlika je prišla do izraza že v uvodnem nizu v drugem in tretjem ko so v mariborski vrsti zaigrale tudi nekatere odbojkarice ki običajno sedijo na rezervni klopi pa je bila igra bolj izenačena
# 318 : pavel pinni na celjski klopi torej še čaka prvi komplet točk tako kot suad beširovič oziroma tomaž kavčič že dalj časa na črnomaljski spomladi to velja tudi za povratnika na ljubljansko klop vojislava simeunoviča ki je bil v novi gorici blizu uspeha
# 319 : panionios je brez pomoči dražena žežlja ki ga ni bilo niti na klopi za rezervne igralce z 2:0 ugnal ionikos kerkyra je na kreti s 4:3 premagala tamkajšnji ofi dino šeremet je srečanje spremljal z gostujoče klopi za rezervne igralce
# 320 : klop 31 hasič 33 božičič 9 bordon 13 plut 10 lovrečič 14 guberac 3 a. puš
# 321 : kratka klop nas sili v to da večina prve postave nekako igra skoraj celotno tekmo
# 322 : 1939 rodil se je italijanski nogometni trener giovanni trapattoni ki zdaj sedi na klopi avstrijskega salzburga v preteklosti pa je bil med drugim strateg juventusa interja milana bayerna in benfice ter v letih 2000 2004 selektor italije
# 323 : klop 40 s. kovačevič 2 nikolič 15 m. kovačevič 20 šturm 19 komel 18 kalakovič 24 demirović
# 324 : slobodan subotič je zato na klop potegnil najboljšega strelca portoričana eliasa ayusa s težavami ki jih ima na mestu organizatorja igre pa je njegova ekipa na trenutke dajala videz naključno zbranih rekreativcev
# 325 : poraz bo pač treba čim prej pozabiti in zdaj kar najboljše izkoristiti prvenstveni premor ter nato nadaljevati v jesenskem slogu je razmišljanje po prespani noči zaključil ajdovski strateg ki seveda še vedno trdno ostaja na klopi rdeče črnih
# 326 : glede na to da je z nami 21 igralcev in za vse niti na klopi ne bo prostora se lahko zgodi tudi to da bo kdo užaljen
# 327 : klop koliqi xhafa pisha bulku berisha salihi bushi
# 328 : nekaj je tudi težav s poškodbami in tako je manjkal eden redkih še aktivnih igralcev iz tistega obdobja agron šalja zgolj za vzdušje na klopi za rezerviste sta skrbela dejan kečan in aleš kodelja medtem ko se je šefik mulahmetović pošalil da žal ne bo nastopil ker ga je trener poslal na tribuno kot četrtega tujca
# 329 : potem ko so si srbski mediji pošteno dali duška za njimi pa prav dosti ni zaostajala niti tamkajšnja javnost varovanci baska na klopi srbije javierja clementeja za lov na podoben podvig ne bi mogli biti bolj motivirani
# 330 : klop 31 šeliga 4 križnik 8 rusič 13 bakarič 11 urbanč 17 korun
# 331 : roman pungartnik je zaradi bolezni obsedel na klopi njegovo moštvo pa je odpor sarajevske bosne ki je prvo tekmo dobila z 20:18 zlomilo šele v drugem delu tekme
# 332 : klop 12 a. adilović 30 vugdalič 8 pavlovič 9 štrbac 17 osredkar 23 jelečevič 29 hanžič
# 333 : tako so domačini ravnotežje v prvem polčasu ohranjali le po zaslugi 20 točk kunca vendar ko je omenjeni igralec na začetku drugega polčasa dobil četrto osebno napako in moral na klop se je razlika hitro povečala
# 334 : toda kljub temu ni prav nobenega dvoma o tem da je končni izid srečanja popolnoma pravičen je portugalski strateg na klopi londončanov presenetil z resnicoljubnostjo in redko videnim izogibanjem kakršnimkoli konfliktnim izjavam
# 335 : beno udrih na derbiju proti phoenix sunsom obsedel na klopi
# 336 : tudi sicer je ljubljanska klop dajala elitnejši videz s simeunovičem šteharnikom štrbcem vugdaličem karičem hanžičem in kitičem kot pa udarna enajsterica a to je stvar in odločitev stroke
# 337 : ni lahko na vroči trenerski klopi niti na dnu niti na vrhu vsak se sooča s svojimi tegobami vsekakor pa lahko mladi domžalski trener spi precej mirneje kot njegov kolega na drugi strani
# 338 : 479 32 nagrajenci1 nagrajenci so trening uniona olimpije spremljali s klopi za rezervne igralce
# 339 : klop 30 suhonjič 19 volaš 20 r. božič 13 plut 6 handanagič 5 lazič 10 lovrečič
# 340 : gorenje je vodilo še z 11:8 a po izključitvi skoka ki se je nespametno odzval na nešportno potezo edvarda kokšarova in moral za dve minuti na klop je prišlo do preobrata
# 341 : še prej je klop gorenja pri 11:10 zahtevala minuto odmora ravno v trenutku ko je boštjan kavaš zadel z igralcem manj
# 342 : goran šukalo koblenz je igral vso tekmo prislužil si je rumeni karton matej mavrič koblenz je sedel na klopi
# 343 : njegov kolega na koprski klopi je bil razumljivo precej bolje razpoložen
# ...
# 2582 : na mizah zraven masa zne klopi so se kopi cile gore brisa c zraven so bile postrojene steklenice z masa znim oljem
# 2583 : minulo nedeljo dopoldne so v prostorih zreškega kinološkega društva ob stadionu v klopi sicer sedli predvsem njihovi lastniki medtem ko so psi uživali zunaj na soncu a se bo kmalu tudi zanje pričel trening
# 2584 : pevnik je na klopi drave zamenjal hrvaškega strokovnjaka milana djuričića ki se je moral posloviti tik pred obračunom z gorico
# 2585 : zbirali bodo dotrajane delno uničene in razpadajoče klopi in jih po celoviti prenovi z umetniškim pridihom postavili na javno mesto natančneje za avtobusno postajo v slovenskih konjicah
# 2586 : vse ki imate kakršnokoli idejo kje vse lahko te klopi dobijo pozivajo da se javite na njihov mail fastartdeluxe@gmail.com ali pokličejo na 031 648 811 nika
# 2587 : slovenske konjice 1. maj na mestnem trgu je nekdo poškodoval klopi in stekli na kiosku
# 2588 : toda koštuničevi poslanci se po sredini odločitvi ustavnega sodišča zrj vračajo v poslanske klopi
# 2589 : na zatožno klop bosta sedla nekdanja člana rasistične organizacije ku klux klan
# 2590 : družbo mu delata kamnita klop in prav tak zid
# 2592 : potem znova v službo v šolske klopi vse od začetka kljub pozabljanju in spominskim motnjam ki so posledica kemoterapije ali pa hormonskih zdravil
# 2598 : ti načini odstranjevanja so uspešni predvsem v primerih ko so klopi prisesani razmeroma kratek čas manj uspešni od odstranjevanja s pinceto pa kadar jih odkrijemo pozno in so zariti globoko v kožo
# 2599 : z njim operemo klopi na katerih se je nabrala zimska umazanija
# 2600 : vendar je tudi klop ki pride s psom ali mačko v naše bivališče lahko potencialni vir bolezni za nas
# 2601 : katanec bo prvo uradno tekmo s klopi vodil šele 6. januarja prihodnje leto ko se bodo zae pomerili z malezijo v sklopu azijskega pokala
# 2602 : policist sedi na klopi v parku ko pride mimo njegov znanec in ga vpraša
# 2603 : na prizorišče so pripeljal štiri komajda do šolskih klopi zrasle otroke ki bi v nočnih urah morali doma spati a so se morali vsiljivo smukati po odru in v različnih prostorih ter ob steklenicah refoška prodajati razglednice zvočne posnetke in drugi kič
# 2604 : če bi potemtakem internet res moral sesti na zatožno klop bi se moral zagovarjati za marsikateri greh
# 2605 : maribor nafta 6:2 medtem ko je bil trener maribora marijan pušnik ponosen na svoje igralce s katerimi je pred tekmo opravil individualne pogovore se je njegov tekmec na klopi nafte milko djurovski jezil na sodnike da so gostitelji drugi gol dosegli iz nedovoljenega položaja
# 2606 : da ima trener miro požun ki je nekoč sedel na klopi pivovarjev protistrup za nekdanje delodajalce je letos že dvakrat dokazal v prvenstvu skupaj pa so velenjčani na zadnjih štirih dvobojih s celjani štirikrat zmagali
# 2607 : na zatožni klopi sta nekdanji makedonski notranji minister ljube boškovski in nekdanji makedonski policijski inšpektor johan tarčulovski ki sta obtožena vojnih zločinov med policijsko akcijo avgusta 2001 v vasi ljuboten severno od skopja
# 2608 : ljubljančane je v ajdovščini znova vodil hrvaški trener dragan skočić ki je klop zapustil po prvem krogu spomladanskega dela prvenstva uradno zaradi družinskih razlogov
# 2609 : opečnata struktura obodnih zidov barva stropa in klopi dajeta temu prostoru podobnemu predstavi o notranjosti grškega antičnega templja neka brezčasno toplino
# 2610 : nogometaš iz trbovelj je tekmo začel na klopi za rezerve v dobrih desetih minutah kolikor je preživel na zelenici pa ni uspel spremeniti poteka tekme
# 2611 : bila je njegova prva ljubezen iz šolskih klopi a jo je zapustil ker ga je menda prevarala z najboljšim prijateljem
# 2612 : ovčji klop verjetno najpogostejš a vrsta klopa v zmernem podnebnem pasu
# 2613 : ovčji klop ixodes ricinus je zunanji parazit ki v glavnem zajeda ovce in govedo občasno pa se spravi tudi na človeka in druge manjš e sesalce
# 2614 : določene bolezni goveda in ovac verjetno prenaš ajo klopi
# 2615 : različice pegavice ki jih prenaš ajo klopi povzročajo r. rickettsii povzroča pegasto vročico skalnega gorovja ki se pojavlja v severni ameriki in južni ameriki r. conori ki jo najdemo ponekod v afriki r. australis ki so pojavlja na nekaterih območjih avstralije
# 2616 : slednjega bo na vroči klopi reala zamenjal nekdanji španski selektor jose antonio camacho
# 2617 : oslabljeni domačini zaradi bolezni in poškodb so manjkali kar štirje igralci kar je ob že tako tenki klopi velika težava pa so pokazali da se s srčno igro lahko merijo tudi z najboljšimi
# 2618 : hotel sem se vrniti na klop mariborskega košarkarskega kluba saj sem dolga leta igral košarko v mariboru bil tudi trener in ni mi vseeno kako igra in kakšne uspehe dosega mariborski klub
# 2619 : 200 cm visoki stefan ki je v zadnjih petih sezonah s spremenljivo srečo nastopal za kar nekaj italijanskih a ligašev je zadnji dve sezoni zaradi poškodbe v glavnem presedel na klopi itasa iz trenta
# 2620 : ranieri vselej šarmantni italijan na klopi chelseaja tokrat ni skrival nezadovoljstva
# 2621 : set vevče potem ko sta jeseni na trenerski klopi sedela jani zavrl in filip mendaš ju je zamenjal miloš rus ki se je vrnil z japonske
# 2622 : v prtljažniku je namreč za 530 litrov prostora signum 365 litrov ob podrtju po tretjini deljive zadnje klopi pa se volumen prtljažnika poveča do 1.850 litrov
# 2623 : gostiteljice so imele veliko pripomb k sodniškim odločitvam zaradi petih osebnih napak pa so na klop odšle temnikova tratiakova kurševičeva perličeva in v podaljšku še potočnikova
# 2625 : še dolgo potem smo vsi trije sedeli na klopi šteli ukradeni denar in ga enakopravno delili na tri dele
# 2626 : skupaj z njim so na zatožno klop sedli tudi 23 letni bojan majstorovič enako star željko balent in 21 letni blaž krošelj vsi so iz ljubljane
# 2627 : z zadnjo klopjo pa lahko prilagajamo velikost prtljažnika pri petvratni različici kjer osnovna prostornina meri 300 litrov ob povsem pomaknjeni klopi naprej pa do 425 litrov
# 2628 : potniki na zadnjih sedežih se bodo poleg teh razveselili tudi nagiba zadnjih naslonov zadnjo klop pa je v različicah se in le možno zložiti v razmerju 40 20 40. in če so vse to majhne novosti potem poglejmo kaj se je pri novem x trailu dejansko spremenilo
# 2629 : kdor vpreže corso v transportne namene bo vesel možnosti zlaganja zadnje klopi v razmerju 60 40
# 2630 : prostora je pravzaprav relativno dovolj povsod če se seveda zavedamo tradicije v tem družinskem premium razredu da na zadnji klopi visokorasli potniki razen bolečin nimajo kaj iskati
# 2631 : notranjost potniškega prostora je kljub večji razdalji od tal enostavno dostopna nižjeraslim z bogato odmerjenimi merami pa osreči tudi višjerasle predvsem na zadnji klopi
# 2632 : prtljažnik ima ravno dno za enostavno nakladanje meri zadovoljivih 410 litrov in ob podrtju zadnje klopi omogoča povečanje na enormnih 1841 litrov
# 2633 : na sredino notranjosti je umeščen salon z mizo ki meri 70 x 115 cm obdajata jo dve klopi široki 120 x 80 cm in 240 x 120 cm
# 2634 : mizo lahko spustimo na višino klopi in uredimo veliko zasilno ležišče
# 2635 : krmno klop je mogoče med regato odmakniti in pustiti na kopnem med počitniškim jadranjem pa bo dobrodošla
# 2636 : osrednji del kokpita zavzemata dve klopi 175 x 46 cm
# 2637 : ker klopi ne skačejo letajo ali pletejo niti je edina možnost da ga dobimo ta da ga poberemo z neposrednim dotikom listja trave podrasti
# 2638 : ko klop zazna našo bližino se pripravi na selitev in ko se dotaknemo lista se nas naglo oprime s prednjima nožicama
# 2639 : čeprav strokovnjaki ne vedo natančnega vzroka se klopi nekaterim izogibajo nekatere pa množično oblegajo
# 2640 : zamenjava na klopi ere šmartno še ni prinesla uspeha saj je borut jarc s svojim novim moštvom visoko izgubil v ajdovščini
# 2641 : primož brezec je sicer še devetič v 13 tekmah sezone presedel vseh 48 minut na klopi vendar mu je v uteho vsaj 11. zmaga indiane ki je celo najuspešnejša med vsemi 29 ekipami
# 2642 : v rumenem bildu pa so ironično pripomnili da če ne bo rojak na tekmečevi klopi ostal brez las bo nemška reprezentanca šla k vragu
# 2644 : v 11. minuti je krkin trener neven spahija ki naj bi kmalu na klopi olimpije nadomestil zmaga sagadina poslal na igrišče tudi visokega skelina toda to se v igri krke ni poznalo
# 2645 : švedski strateg na angleški klopi je dvoboj začel s postavo ki je končala tekmo proti argentini
# 2646 : v prihodnji sezoni bo ekipo vodil dragutin baltič skupaj z njim bo na klopi tudi radovan gačič
# 2647 : tone tiselj tudi uradno na klopi ženske ekipe koldinga
# 2648 : čeprav so mnogi poudarjali da udarna enajsterica francoske izbrane vrste v primerjavi s prvim srečanjem potrebuje korenite spremembe je domenech zamenjal le enega povrh vsega je na klopi pustil enega od najbolj razpoloženih mož na prvi tekmi francka riberyja
# 2649 : domenech zidane zinedine zidane ob selitvi na klop močno kritiziranega francoskega selektorja raymonda domenecha ni niti pogledal
# 2650 : a nihče se ne bi približal vezistu liverpoola ki je takoj po vstopu v igro s klopi za rezerve prejel neverjetno darilo vratarja dide ki bi ob drugačnem razpletu v boju za napako dneva gotovo ugnal mehiškega sodnika a je iz neposredne bližine zgrešil prazna vrata
# 2651 : brazilski rezervisti so namreč še kako lačni igre tudi forma nekaterih nogometašev ki so prvi dve srečanji začeli na klopi v prvi vrsti tu mislimo na robinha freda in juninha pa se zdi boljša najmanj od forme obeh omenjenih napadalcev verjetno pa tudi od forme prvega zvezdnika ronaldinha
# 2652 : zico priskočili na pomoč zicu brazilcu na japonski klopi
# 2653 : tudi z drogbajem ki je tekmo spremljal s klopi in vnetno navijal
# 2654 : harry to vsekakor je in vesel sem da mu je uspelo je o njem povedal nizozemec na avstralski klopi
# 2655 : in da zaradi tega na klopi sedi hitri in spretni luka modrić ki bi lahko naredil razliko
# 2656 : že nekaj časa je znano da zmagovalce pokala slovenije v novi sezoni ne bo več vodil dragutin baltič ki se je preselil na blejsko klop kdo bo njegov naslednik pa naj bi v vodstvu kluba objavili šele prihodnji teden
# 2657 : največji tekmec ivice osima za klop samurajev naj bi bil nekdanji francoski reprezentant didier deschamps ki je nazadnje sedel na klopi monaca
# 2658 : kako bi jo tudi pričakoval ko pa je šved na klopi enega izmed favoritov prvenstva dve težavi rešil na naravnost neverjeten način
# 2659 : švedski strateg na klopi otoške izbrane vrste je po tekmi priznal da je bil rezultat boljši od igre
# 2660 : nobenega dvoma ni da je dejavnik presenečenja uspel kljub temu da je na nasprotni klopi sedel morda celo najboljši trener na svetu guus hiddink a na italijansko žalost ni uspel v popolnosti
# 2661 : hiddink kljub izpadu v osmini finala je guus hiddink svoje delo tudi na avstralski klopi opravil odlično in potrdil sloves najboljšega trenerja na svetu
# 2662 : na brazilski klopi tako vsekakor ne bi smelo več biti prostora za parreiro ki pač mora plačati davek brazilskemu neuspehu
# 2663 : ko je poslal na igrišče alessandra del piera se je obrnil h klopi in dejal sodelavcem zapomnite si dosegel bo odločilni zadetek
# 2664 : res je tudi on je tu in še enajst drugih ki vsako tekmo začnejo na klopi za rezervne igralce in so seveda željni igranja
# 2665 : ni užaljenosti vsak je pripravljen pomagati tudi na takšen način da na svojo priložnost čaka na klopi za rezervne igralce kjer je brez dvoma še težje kot na igrišču
# 2666 : čestitke izrekam tudi vsem ki so na klopi ne le enemu ampak vsem dvanajstim je o tem povedal domenech ki torej hvali vzdušje v francoski reprezentanci in gotovo ne želi izpostavljati problema ki je bil zaradi užaljenosti vratarja gregoryja coupeta izpostavljen že pred prvenstvom
# 2667 : slovenski prvaki so na severno irsko odpotovali brez saša raniča ki je bil še lani izbran za najboljšega igralca lige zdaj zanj v gorici ni več prostora niti na klopi
# 2668 : na klop se je vrnil borut rebič mož ki je termo popeljal do zgodovinskih uspehov in nastopa v evropskem pokalu
# 2669 : še več trenerski dvojec giovanni trapattoni lothar matthäus oziroma trapatthäus ljubljanskega branilca ni uvrstil niti na klop za rezervne igralce
# 2670 : nagradno vprašanje ali mislite da bosta prva dva od omenjenih pogosto grela klop za rezervne igralce
# 2671 : mactavish je na klopi kanadskega moštva že pet sezon pred tem pa je kot igralec z edmontonom osvojil tri stanleyjeve pokale
# 2672 : klop barbosa gonzalo edu de la bella marcos bruno jonathan
# 2673 : pires robert pires v sredini danes zvečer gotovo ne bo sedel na klopi za rezervne igralce
# 2674 : lani smo imeli prekratko klop za enakovreden boj v vseh tekmovanjih tokrat bomo storili vse za uspeh na domačem prizorišču
# 2675 : res pa je da sem bil po zaključku prejšnje sezone razočaran s sedenjem na klopi in sem od klubskega vodstva zahteval odgovor ali name še računajo
# 2676 : strateg z ježiške klopi pa bo seveda zadnje dni izkoristil tudi za odpravo zadnjih pomanjkljivosti
# 2677 : klop todorov cichero ljubenov palankov manolev hazurov popov
# 2678 : klop germič tisnikar a. zajc prejac zečevič drevenšek
# 2679 : proti odličnemu bloku argentincev nismo našli pravega orožja je po dveh porazih dejal mauro berutto italijan na klopi finske reprezentance
# 2680 : malce preveč treme je imel škrbina bržčas pa je bilo za to vzrok zveneče ime našega nasprotnika je dodal žilnik ki je tako uspešno prestal prvoligaški debi na klopi publikuma
# 2681 : borut jarc ki je na koprski klopi vnovič sedel namesto milivoja bračuna se ravno tako ni mogel izogniti omembi obeh herojev ulice ki sta tokrat nagnila tehtnico vstop juniorja je zelo poživil našo igro čeprav še ni povsem pripravljen poleg tega čuti bolečine v rami
# 2682 : letos je šele moja druga sezona na klopi ruske reprezentance in v tem obdobju smo veliko delali predvsem na tehniki in taktiki veliko poudarka pa smo posvečali obrambi in s tem seveda protinapadu
# 2683 : nekdanji branilec gorice je tekmo začel na klopi za rezervne igralce v igro je vstopil v 70. minuti
# 2684 : marko kmetec je v ciprski ekipi zaigral od prve minute patrik ipavec je tekmo začel na klopi za rezervne igralce drugih informacij iz belgije žal ni bilo
# 2685 : nekdanji trener mure je odlično začel hrvaško prvenstvo na klopi zagreba na kateri je nasledil slovenskega strokovnjaka
# 2686 : zame je jahta ko sedim na trenerski klopi in trepetam za rezultat svoje ekipe je v svojem slogu sklenil ćiro blažević
# 2687 : tudi tokrat bo na igrišče poslal nespremenjeno enajsterico manjšo novost bo doživela le rezervna klop na treningu si je jan vidic poškodoval gleženj tako da bo nekaj dni počival
# 2688 : klop 22 bratušek 3 džinič 21 pokleka 7 amel mujakovič 10 rakič 25 g. zajc 38 satler
# 2689 : klop 1 varkaš 5 kitič 11 prudič 12 simič 14 ihbeisheh 17 osredkar 22 jelečevič
# 2690 : klop 1 germič 3 toplak 7 a. zajc 13 prejac 20 drevenšek 11 bošnjak
# 2691 : klop bučar hankič jahič hudarin rajkovič jelen lalovič
# 2692 : s tem pridemo do naslednjega problema igralec ki je na klopi ne more reagirati
# 2693 : za bojana malačiča je bila sobotna tekma bržčas zadnja na klopi nafte
# 2694 : morda lahko zaidejo v težave proti conski obrambi kar se jim je dogajalo na olimpijskih igrah v atenah vendar so prav zato na klop pripeljali tudi mika d'antonija trenerja phoenixa ki evropsko košarko pozna zelo dobro
# 2695 : v njem sta na klopi sedela temnopolta velikana in od daleč sva začela ugibati ali ne gre morda za košarkarja
# 2696 : mislim da bom priložnost s klopi dobival vse do konca sezone čaka nas še enajst prvenstvenih tekem
# 2697 : ker želi imeti na klopi igralce ki lahko poskrbijo za spremembo ritma v nadaljevanju tekme je zelo verjetno da bosta v tej vlogi poleg miheliča strelca zadetka za 1:2 v beogradu in krivca za ozračje napetega odštevanja do začetnega žvižga francoskega sodnika še rakič in mujakovič
# 2698 : odleglo je tudi njegovemu kolegu na klopi valencie quiquu sanchezu floresu čigar varovanci so si pred štirinajstimi dnevi v salzburgu zelo zapletli življenje
# 2699 : klop 22 rutar 2 mehanovič 7 kalin 15 škerjanc 6 bunderla 3 džuzdanovič 24 kosmač

# %%
for sent in all_sentences[-10:]:
    print( ' '.join(sent))
# Out:
# tam je gol stal carlin mož in divje masturbiral pripoveduje mark
# discipline gospodar ni vsiljeval toliko z golo silo kot s svojo karizmo skupnostni obedi in obredi so bili sestanki posvetovalnih teles glavni vzvod discipliniranja pa so bile ceremonije 30
# 3 goli larsson švedska tomasson danska lampard anglija zidane francija
# po golu gutalja je zadel še škaper ki je čez slabih deset minut povedel domače v vodstvo s 3:0
# gole zametke v fazi nastajanja ki so samo pomotoma javni
# po prvem domačem golu zabil ga je brian mcbride je sodnik razveljavil njihov gol in dvakrat ni pokazal na belo točko ko bi lahko nakar je na drugi strani pape bouba diop v 35. minuti zabil odločilni drugi gol
# čeprav so domači rokometaši prvo tekmo izgubili za devet golov je bila dvorana v ormožu premajhna za vse ljubitelje rokometa
# drugi gol so potem sicer pripisali traubu kot strelcu avtogola kar niti ni tako pomembno
# s 17 ali 18 goli je lavrič sezono končal tudi reprezentančno kot drugi najboljši strelec druge nemške lige
# stevanovic gol dalibor stevanovič je z zadetkom v 64. minuti zapečatil usodo zeleno belih

# %%
len(all_sentences)
# Out:
# 2673
